# %%
from xml.dom import minidom
import regex

# %%
# structure to expect:
#	onixmessage
#		product
#			publishingdetail
#				salesrights
#					territory
#						countriesincluded/‘worldwide with specified exclusions’/worldwide/etc.

# onix message- mandatory

# product- can expect multiple per file

# publishingdetail- "It is mandatory in any <Product> record unless the <NotificationType> in Group P.1 indicates that the record is an update notice which carries only those blocks in which changes have occurred."

# salesrights- "allows rights to be specified as exclusive or non-exclusive or not-for-sale in any combination of countries or regions. It is also possible to specify rights as ‘worldwide’ or ‘worldwide with specified exclusions’ if this enables them to be stated more concisely."

# territory- "non-repeating. If omitted, the text is intended for use wherever the product may be sold"

# %% [markdown]
# # tool functions

# %%
######### some styling functions to make error reporting more legible. ########

def boldQuote(content):
    out =  '\033[91m'+'\033[1m'+'"'+ content +'"'+'\033[0m'
    return out

def notify(content):
    out =  '\033[95m'+ content +'\033[0m'
    return out

def error(content):
    out =  '\033[91m'+'\033[1m'+ content +'\033[0m'
    return out

######### clean tag name for checks to allow for caps, whitespace, punctuation etc. ########
# A good way to extend this out would be to check for 
# eg. common spelling mistakes.

def cleanText(string):
    
    #clean out whitespace
    out = string.replace(" ", "")
    
    #revert to lowercase
    out = out.lower()
    
    #clean all punctuation and non latin characters (excluding numbers)
    cleanout = regex.sub('[^a-zA-Z0-9]', u'', out)
    
    if(cleanout != out):
        print ('XML tag',boldQuote(out),'translated to',boldQuote(cleanout))

    return cleanout


def searchLayer( layer, searchTerm, prevLayer ):
    
    # see whether we have multiple tags and report back.
    if (len(layer) > len(prevLayer)):
        multTagName = layer[0].tagName
        print(notify('number of '+ multTagName + ' tags in ' + currentFile + ' is greater than 1'))
        permittedNumberOfTags = len(layer)
    
    # childNodes can't be found if the div isn't an element, so use except to skip other types
    # pull out all tags which have a name matching our searchterm, and collect them in an array
    # which we will push into currentTag.
    
    try:
        
        out = []
        
        for i in range(len(layer)):
            items = layer[i].childNodes

            for item in items:
                try:
                    elementTag = cleanText(item.tagName)
                    if (elementTag == searchTerm):
                        out.append(item)
                except:
                    pass

            if (len(out) == 0):
                print(error('no ' + searchTerm + ' tag found in ' + currentFile))
                
        return out
    
    except:
        pass
    
def getBookNames(currentTitleTag, titleTagTypes):
    bookNamesInFile = []
    for i in range(len(currentTitleTag)):
        bookName = ""
        for node in currentTitleTag[i].childNodes:
            try:
                titleTag = node.childNodes[0]
                title = titleTag.nodeValue
                
                if (cleanText(node.tagName) in titleTagTypes):
                    if(len(bookName) > 0):
                        bookName += " "
                    bookName += title
            except:
                pass
        bookNamesInFile.append(bookName)
    return bookNamesInFile

def getCountryLists(currentCountryTag):
    countryListsInFile = []
    for i in range(len(currentCountryTag)):
        for node in currentCountryTag[i].childNodes:
            try:
                #we only want nodes which have a childnode, as countrylists are stored
                #within the childnode. I'm going to assume they aren't going to be 
                #badly written and stored in eg. tagnames for the scope of this project.

                countriesTag = node.childNodes[0].nodeValue                
                countriesArray = countriesTag.split()
                
                checkDeprecatedCountryCodes(countriesArray)
                
                # IMPORTANT NOTE: ‘worldwide with specified exclusions’ is a permitted format for territory. 
                # This checks for that case.
                countriesArray = checkExcluded(countriesArray)

            except:
                pass
        
        countriesArray = checkWorld(countriesArray, allCountries)
            
        countryListsInFile.append(countriesArray)
    return countryListsInFile

# %% [markdown]
# # test functions

# %%
def checkDeprecatedCountryCodes(countriesArray):
    for countryCode in countriesArray:
        if (countryCode == "YU" or countryCode =="CS" or countryCode == 'AN'):
            print(error('WARNING: country code "' + countryCode + '" in territories for "' + bookName + '" in '+ currentFile +' is deprecated'))

def checkWorld(countriesArray, allCountries):
    if (cleanText(countriesArray[0]) == 'world'):
        countriesArray = allCountries
    return countriesArray

# countries list gathered from here: https://www.editeur.org/files/ONIX%20for%20books%20-%20code%20lists/ONIX_BookProduct_Codelists_Issue_49.html
# list 91. with CS - Serbia & Montenegro, AN- Netherlands Antilles and 
# YU - Yugoslavia excluded. 
# Warnings are given below for deprecated CS, AN, and YU countrycodes.

def checkExcluded(countriesArray):
    if (cleanText(node.tagName) == 'countriesexcluded' or cleanText(node.tagName) == 'x451'):
        subtractedCountriesArray = allCountries
        for i in range(len(countriesArray)):
            if( countriesArray[i] in subtractedCountriesArray ):
                subtractedCountriesArray.remove(countriesArray[i])                        
        countriesArray = subtractedCountriesArray
    return countriesArray

def checkMissingTerritoryTag(currentCountryTag, countryLists, allCountries):
    # "If <territory tag> is omitted, the text is intended for use 
    # wherever the product may be sold" - Onix Format specification
    if (len(currentCountryTag) == 0):
        print(notify('no territory tag so all countries included'))
        countriesArray = allCountries
        countryLists.append(countriesArray)
    return countryLists
    
def checkTitleCountriesLengths(bookNames, countryLists):
    if(len(bookNames) != len(countryLists)):
        print(error('WARNING: different number of book names found in file than territory codes.'))

# %% [markdown]
# # process the data

# %%
docs = ['1','2','3','4']
# docs=["test2"]
# docs=["test"]

# strictly speaking, we should probably search for information on permitted countries of sale
# within all tags within the salesrights div, as this is the extent of the purpose of
# the salesrights div, (and I think it is likely for salesrights information to be misplaced 
# outside of a territory tag) but 'territory' is specified in the ONIX documentation as 
# non-repeating, and, if ommitted, 'the text is intended for use whereever it may be sold', 
# so I will default to that understanding.

# so, we want to 'dig down' through all of these tagNames to find our countrylist

# NOTE: short tags for all of the following searchtags are lowercase, so are searched 
# for with .lower().

tagNamesCountries = ['product', 'publishingdetail', 'salesrights', 'territory']
tagNamesTitle = ['product', 'descriptivedetail', 'titledetail', 'titleelement']

# tags which could contain title information for the book in question.
# partnumbers and annual numbers and subtitles included/appended to 
# improve the chances of titles being unique.

titleTagTypes = ['titletext', 'b203', 'titlewithoutprefix', 'b031', 'yearofannual', 'b020', 'partnumber', 'x410', 'subtitle', 'b029']

# countries list gathered from here: https://www.editeur.org/files/ONIX%20for%20books%20-%20code%20lists/ONIX_BookProduct_Codelists_Issue_49.html
# list 91. with CS - Serbia & Montenegro, AN- Netherlands Antilles and 
# YU - Yugoslavia excluded. 

allCountries = ['AD', 'AE', 'AF', 'AG', 'AI', 'AL', 'AM', 'AO', 'AQ', 'AR', 'AS', 'AT', 'AU', 'AW', 'AX', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BL', 'BM', 'BN', 'BO', 'BQ', 'BR', 'BS', 'BT', 'BV', 'BW', 'BY', 'BZ', 'CA', 'CC', 'CD', 'CF', 'CG', 'CH', 'CI', 'CK', 'CL', 'CM', 'CN', 'CO', 'CR', 'CU', 'CV', 'CW', 'CX', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'EH', 'ER', 'ES', 'ET', 'FI', 'FJ', 'FK', 'FM', 'FO', 'FR', 'GA', 'GB', 'GD', 'GE', 'GF', 'GG', 'GH', 'GI', 'GL', 'GM', 'GN', 'GP', 'GQ', 'GR', 'GS', 'GT', 'GU', 'GW', 'GY', 'HK', 'HM', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IM', 'IN', 'IO', 'IQ', 'IR', 'IS', 'IT', 'JE', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KP', 'KR', 'KW', 'KY', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK', 'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MC', 'MD', 'ME', 'MF', 'MG', 'MH', 'MK', 'ML', 'MM', 'MN', 'MO', 'MP', 'MQ', 'MR', 'MS', 'MT', 'MU', 'MV', 'MW', 'MX', 'MY', 'MZ', 'NA', 'NC', 'NE', 'NF', 'NG', 'NI', 'NL', 'NO', 'NP', 'NR', 'NU', 'NZ', 'OM', 'PA', 'PE', 'PF', 'PG', 'PH', 'PK', 'PL', 'PM', 'PN', 'PR', 'PS', 'PT', 'PW', 'PY', 'QA', 'RE', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SD', 'SE', 'SG', 'SH', 'SI', 'SJ', 'SK', 'SL', 'SM', 'SN', 'SO', 'SR', 'SS', 'ST', 'SV', 'SX', 'SY', 'SZ', 'TC', 'TD', 'TF', 'TG', 'TH', 'TJ', 'TK', 'TL', 'TM', 'TN', 'TO', 'TR', 'TT', 'TV', 'TW', 'TZ', 'UA', 'UG', 'UM', 'US', 'UY', 'UZ', 'VA', 'VC', 'VE', 'VG', 'VI', 'VN', 'VU', 'WF', 'WS', 'YE', 'YT', 'ZA', 'ZM', 'ZW']

allBooks = []
bookNames = []
countryLists = []


for doc in docs:
    
    currentFile = doc + '.xml'
    mydoc = minidom.parse( currentFile )
    
    try:
        onixWrapper = mydoc.getElementsByTagName("ONIXmessage")
    except IndexError:
        print('no ONIX Wrapper in ' + currentFile)
        pass
    
    currentCountryTag = onixWrapper
    currentTitleTag = onixWrapper
    prevTag = currentCountryTag
    
    # use the searchLayer function to check the file for tags of the right tagName,
    # collect them in an array and then search those tags for the next correct tagName
    # to find the nesting where the countries info is stored.
    # includes error reporting and checks
    
    for layer in tagNamesCountries:
        newTag = searchLayer(currentCountryTag, layer, prevTag)
        prevTag = currentCountryTag
        currentCountryTag = newTag
        
    for layer in tagNamesTitle:
        currentTitleTag = searchLayer(currentTitleTag, layer, prevTag)
        
    # get the titles of the books in the file
    
    bookNamesInFile = getBookNames(currentTitleTag, titleTagTypes)
    bookNames.extend(bookNamesInFile)
    
    # get the permitted countries of sale for each book
    
    countryListsInFile = getCountryLists(currentCountryTag)
    countryLists.extend(countryListsInFile)
    
    countryLists = checkMissingTerritoryTag(currentCountryTag, countryLists, allCountries)
    
    checkTitleCountriesLengths(bookNames, countryLists)
    
# now that we've finally found all the book names and territory lists in all the files, 
# put them in a dictionary so they're nice and straightforward to put in a database.
# this could be easily extended to include more info.
    
for i in range(len(bookNames)):    
    book = {}
    book['title'] = bookNames[i]
    book['countries'] = countryLists[i]
    allBooks.append(book)

# print(allBooks)

# %% [markdown]
# # databasing

# %%
import mysql
import sqlalchemy as sqla
from sqlalchemy.sql import text
metadata = sqla.MetaData()


host = 'sql2.freesqldatabase.com'
database_name = 'sql2395730'
user = 'sql2395730'
password = 'fL7!xU9%'
port = '3306'

engine = sqla.create_engine(
    'mysql+mysqlconnector://'+user+':'+password+'@'+host+':'+port+'/'+database_name
)

# %%
#SQL queries to build the tables

# #World record longest title of a book consists of 26,021 characters, text can have 65,535 chars.
createBookTable  = text("""CREATE TABLE Books ( 
     id int primary key not null auto_increment,
     Title text
    )""")

# #Longest permitted country code by ONIX standards is 2,  30 is plenty
createCountryTable  = text("""CREATE TABLE Countries (
   id int primary key not null auto_increment,
   Country varchar(30)
    )""")

createBookRightsTable  = text("""CREATE TABLE BookRights (
   CountryID int references Countries(ID),
   BookID int references Books(id),
   constraint pk_Books primary key (CountryID, BookID)
   )""")

#Build the tables
# conn = engine.connect()
# conn.execute(createBookTable)
# conn.execute(createCountryTable)
# conn.execute(createBookRightsTable)
# conn.close()

# %%
#Fill the Books and Countries Tables

print(engine.table_names())

def insertIntoDb( data, table, column ):
    try:
        insert_query = text("""INSERT INTO """ + table + """ 
                       ("""+column+""") 
                       VALUES(:title)""")

        conn.execute(insert_query, data)

    except (Exception) as error :
        print(data)
        print("Failed to insert record into table:", error)
        raise error

conn = engine.connect()

# duplicates if more books are added- would be good as an extension to check if the book already exists
# in the database and return a warning. 

# for book in bookNames:
#     bookItem = {}
#     bookItem['title'] = book
#     record_to_insert = ( bookItem )
#     insertIntoDb( record_to_insert, 'Books', 'Title' )
    
# only run once because we have a set list of possible country codes

# for country in allCountries:
#     countryItem = {}
#     countryItem['title'] = country
#     record_to_insert = ( countryItem )
#     insertIntoDb( record_to_insert, 'Countries', 'Country')
    
conn.close()
# Out:
# ['BookRights', 'Books', 'Countries']

# %%
def crossReference( data, table, column ):
    try:
        insert_query = text("""INSERT INTO """ + table + """ 
                       ("""+column+""") 
                       VALUES(:title)""")

        conn.execute(insert_query, data)

    except (Exception) as error :
        print(data)
        print("Failed to insert record into table:", error)
        raise error
    
conn = engine.connect()

for book in allBooks:
    bookResult = conn.execute("SELECT id FROM Books WHERE Title = '"+ book['title'] +"'")
    bookID = bookResult.fetchone()[0]
    
    for country in book['countries']:

        countryResult = conn.execute("SELECT id FROM Countries WHERE Country = '"+ country +"'")
        
#         print('inserting',book['title'], bookID, country, '...')
        
        #if the countryID exists (is not deprecated), insert the data relation, otherwise pass.
        countryIDItem = countryResult.fetchone()
        if countryIDItem:
            countryID = countryIDItem[0]

            print('inserting',book['title'], bookID, country, countryID,'...')

            insert_query = text("""INSERT into BookRights(BookID, CountryID) 
                            VALUES("""+ str(bookID) + """,""" + str(countryID) + """)""" )

            conn.execute(insert_query)
        
        else:
            print(error('skipping '+ str(country) +' as ID is not found in permitted countries table'))

print('finished, closing connection')
conn.close()
# Out:
# inserting Demo The Demo Book 33 AD 254 ...
# inserting Demo The Demo Book 33 AE 255 ...
# inserting Demo The Demo Book 33 AF 256 ...
# inserting Demo The Demo Book 33 AG 257 ...
# inserting Demo The Demo Book 33 AI 258 ...
# inserting Demo The Demo Book 33 AL 259 ...
# inserting Demo The Demo Book 33 AM 260 ...
# inserting Demo The Demo Book 33 AO 261 ...
# inserting Demo The Demo Book 33 AQ 262 ...
# inserting Demo The Demo Book 33 AR 263 ...
# inserting Demo The Demo Book 33 AS 264 ...
# inserting Demo The Demo Book 33 AT 265 ...
# inserting Demo The Demo Book 33 AU 266 ...
# inserting Demo The Demo Book 33 AW 267 ...
# inserting Demo The Demo Book 33 AX 268 ...
# inserting Demo The Demo Book 33 AZ 269 ...
# inserting Demo The Demo Book 33 BA 270 ...
# inserting Demo The Demo Book 33 BB 271 ...
# inserting Demo The Demo Book 33 BD 272 ...
# inserting Demo The Demo Book 33 BE 273 ...
# inserting Demo The Demo Book 33 BF 274 ...
# inserting Demo The Demo Book 33 BG 275 ...
# inserting Demo The Demo Book 33 BH 276 ...
# inserting Demo The Demo Book 33 BI 277 ...
# inserting Demo The Demo Book 33 BJ 278 ...
# inserting Demo The Demo Book 33 BL 279 ...
# inserting Demo The Demo Book 33 BM 280 ...
# inserting Demo The Demo Book 33 BN 281 ...
# inserting Demo The Demo Book 33 BO 282 ...
# inserting Demo The Demo Book 33 BQ 283 ...
# inserting Demo The Demo Book 33 BR 284 ...
# inserting Demo The Demo Book 33 BS 285 ...
# inserting Demo The Demo Book 33 BT 286 ...
# inserting Demo The Demo Book 33 BV 287 ...
# inserting Demo The Demo Book 33 BW 288 ...
# inserting Demo The Demo Book 33 BY 289 ...
# inserting Demo The Demo Book 33 BZ 290 ...
# inserting Demo The Demo Book 33 CA 291 ...
# inserting Demo The Demo Book 33 CC 292 ...
# inserting Demo The Demo Book 33 CD 293 ...
# inserting Demo The Demo Book 33 CF 294 ...
# inserting Demo The Demo Book 33 CG 295 ...
# inserting Demo The Demo Book 33 CH 296 ...
# inserting Demo The Demo Book 33 CI 297 ...
# inserting Demo The Demo Book 33 CK 298 ...
# inserting Demo The Demo Book 33 CL 299 ...
# inserting Demo The Demo Book 33 CM 300 ...
# inserting Demo The Demo Book 33 CN 301 ...
# inserting Demo The Demo Book 33 CO 302 ...
# inserting Demo The Demo Book 33 CR 303 ...
# inserting Demo The Demo Book 33 CU 304 ...
# inserting Demo The Demo Book 33 CV 305 ...
# inserting Demo The Demo Book 33 CW 306 ...
# inserting Demo The Demo Book 33 CX 307 ...
# inserting Demo The Demo Book 33 CY 308 ...
# inserting Demo The Demo Book 33 CZ 309 ...
# inserting Demo The Demo Book 33 DE 310 ...
# inserting Demo The Demo Book 33 DJ 311 ...
# inserting Demo The Demo Book 33 DK 312 ...
# inserting Demo The Demo Book 33 DM 313 ...
# inserting Demo The Demo Book 33 DO 314 ...
# inserting Demo The Demo Book 33 DZ 315 ...
# inserting Demo The Demo Book 33 EC 316 ...
# inserting Demo The Demo Book 33 EE 317 ...
# inserting Demo The Demo Book 33 EG 318 ...
# inserting Demo The Demo Book 33 EH 319 ...
# inserting Demo The Demo Book 33 ER 320 ...
# inserting Demo The Demo Book 33 ES 321 ...
# inserting Demo The Demo Book 33 ET 322 ...
# inserting Demo The Demo Book 33 FI 323 ...
# inserting Demo The Demo Book 33 FJ 324 ...
# inserting Demo The Demo Book 33 FK 325 ...
# inserting Demo The Demo Book 33 FM 326 ...
# inserting Demo The Demo Book 33 FO 327 ...
# inserting Demo The Demo Book 33 FR 328 ...
# inserting Demo The Demo Book 33 GA 329 ...
# inserting Demo The Demo Book 33 GB 330 ...
# inserting Demo The Demo Book 33 GD 331 ...
# inserting Demo The Demo Book 33 GE 332 ...
# inserting Demo The Demo Book 33 GF 333 ...
# inserting Demo The Demo Book 33 GG 334 ...
# inserting Demo The Demo Book 33 GH 335 ...
# inserting Demo The Demo Book 33 GI 336 ...
# inserting Demo The Demo Book 33 GL 337 ...
# inserting Demo The Demo Book 33 GM 338 ...
# inserting Demo The Demo Book 33 GN 339 ...
# inserting Demo The Demo Book 33 GP 340 ...
# inserting Demo The Demo Book 33 GQ 341 ...
# inserting Demo The Demo Book 33 GR 342 ...
# inserting Demo The Demo Book 33 GS 343 ...
# inserting Demo The Demo Book 33 GT 344 ...
# inserting Demo The Demo Book 33 GU 345 ...
# inserting Demo The Demo Book 33 GW 346 ...
# inserting Demo The Demo Book 33 GY 347 ...
# inserting Demo The Demo Book 33 HK 348 ...
# inserting Demo The Demo Book 33 HM 349 ...
# inserting Demo The Demo Book 33 HN 350 ...
# inserting Demo The Demo Book 33 HR 351 ...
# inserting Demo The Demo Book 33 HT 352 ...
# inserting Demo The Demo Book 33 HU 353 ...
# inserting Demo The Demo Book 33 ID 354 ...
# inserting Demo The Demo Book 33 IE 355 ...
# inserting Demo The Demo Book 33 IL 356 ...
# inserting Demo The Demo Book 33 IM 357 ...
# inserting Demo The Demo Book 33 IN 358 ...
# inserting Demo The Demo Book 33 IO 359 ...
# inserting Demo The Demo Book 33 IQ 360 ...
# inserting Demo The Demo Book 33 IR 361 ...
# inserting Demo The Demo Book 33 IS 362 ...
# inserting Demo The Demo Book 33 IT 363 ...
# inserting Demo The Demo Book 33 JE 364 ...
# inserting Demo The Demo Book 33 JM 365 ...
# inserting Demo The Demo Book 33 JO 366 ...
# inserting Demo The Demo Book 33 JP 367 ...
# inserting Demo The Demo Book 33 KE 368 ...
# inserting Demo The Demo Book 33 KG 369 ...
# inserting Demo The Demo Book 33 KH 370 ...
# inserting Demo The Demo Book 33 KI 371 ...
# inserting Demo The Demo Book 33 KM 372 ...
# inserting Demo The Demo Book 33 KN 373 ...
# inserting Demo The Demo Book 33 KP 374 ...
# inserting Demo The Demo Book 33 KR 375 ...
# inserting Demo The Demo Book 33 KW 376 ...
# inserting Demo The Demo Book 33 KY 377 ...
# inserting Demo The Demo Book 33 KZ 378 ...
# inserting Demo The Demo Book 33 LA 379 ...
# inserting Demo The Demo Book 33 LB 380 ...
# inserting Demo The Demo Book 33 LC 381 ...
# inserting Demo The Demo Book 33 LI 382 ...
# inserting Demo The Demo Book 33 LK 383 ...
# inserting Demo The Demo Book 33 LR 384 ...
# inserting Demo The Demo Book 33 LS 385 ...
# inserting Demo The Demo Book 33 LT 386 ...
# inserting Demo The Demo Book 33 LU 387 ...
# inserting Demo The Demo Book 33 LV 388 ...
# inserting Demo The Demo Book 33 LY 389 ...
# inserting Demo The Demo Book 33 MA 390 ...
# inserting Demo The Demo Book 33 MC 391 ...
# inserting Demo The Demo Book 33 MD 392 ...
# inserting Demo The Demo Book 33 ME 393 ...
# inserting Demo The Demo Book 33 MF 394 ...
# inserting Demo The Demo Book 33 MG 395 ...
# inserting Demo The Demo Book 33 MH 396 ...
# inserting Demo The Demo Book 33 MK 397 ...
# inserting Demo The Demo Book 33 ML 398 ...
# inserting Demo The Demo Book 33 MM 399 ...
# inserting Demo The Demo Book 33 MN 400 ...
# inserting Demo The Demo Book 33 MO 401 ...
# inserting Demo The Demo Book 33 MP 402 ...
# inserting Demo The Demo Book 33 MQ 403 ...
# inserting Demo The Demo Book 33 MR 404 ...
# inserting Demo The Demo Book 33 MS 405 ...
# inserting Demo The Demo Book 33 MT 406 ...
# inserting Demo The Demo Book 33 MU 407 ...
# inserting Demo The Demo Book 33 MV 408 ...
# inserting Demo The Demo Book 33 MW 409 ...
# inserting Demo The Demo Book 33 MX 410 ...
# inserting Demo The Demo Book 33 MY 411 ...
# inserting Demo The Demo Book 33 MZ 412 ...
# inserting Demo The Demo Book 33 NA 413 ...
# inserting Demo The Demo Book 33 NC 414 ...
# inserting Demo The Demo Book 33 NE 415 ...
# inserting Demo The Demo Book 33 NF 416 ...
# inserting Demo The Demo Book 33 NG 417 ...
# inserting Demo The Demo Book 33 NI 418 ...
# inserting Demo The Demo Book 33 NL 419 ...
# inserting Demo The Demo Book 33 NO 420 ...
# inserting Demo The Demo Book 33 NP 421 ...
# inserting Demo The Demo Book 33 NR 422 ...
# inserting Demo The Demo Book 33 NU 423 ...
# inserting Demo The Demo Book 33 NZ 424 ...
# inserting Demo The Demo Book 33 OM 425 ...
# inserting Demo The Demo Book 33 PA 426 ...
# inserting Demo The Demo Book 33 PE 427 ...
# inserting Demo The Demo Book 33 PF 428 ...
# inserting Demo The Demo Book 33 PG 429 ...
# inserting Demo The Demo Book 33 PH 430 ...
# inserting Demo The Demo Book 33 PK 431 ...
# inserting Demo The Demo Book 33 PL 432 ...
# inserting Demo The Demo Book 33 PM 433 ...
# inserting Demo The Demo Book 33 PN 434 ...
# inserting Demo The Demo Book 33 PR 435 ...
# inserting Demo The Demo Book 33 PS 436 ...
# inserting Demo The Demo Book 33 PT 437 ...
# inserting Demo The Demo Book 33 PW 438 ...
# inserting Demo The Demo Book 33 PY 439 ...
# inserting Demo The Demo Book 33 QA 440 ...
# inserting Demo The Demo Book 33 RE 441 ...
# inserting Demo The Demo Book 33 RO 442 ...
# inserting Demo The Demo Book 33 RS 443 ...
# inserting Demo The Demo Book 33 RU 444 ...
# inserting Demo The Demo Book 33 RW 445 ...
# inserting Demo The Demo Book 33 SA 446 ...
# inserting Demo The Demo Book 33 SB 447 ...
# inserting Demo The Demo Book 33 SC 448 ...
# inserting Demo The Demo Book 33 SD 449 ...
# inserting Demo The Demo Book 33 SE 450 ...
# inserting Demo The Demo Book 33 SG 451 ...
# inserting Demo The Demo Book 33 SH 452 ...
# inserting Demo The Demo Book 33 SI 453 ...
# inserting Demo The Demo Book 33 SJ 454 ...
# inserting Demo The Demo Book 33 SK 455 ...
# inserting Demo The Demo Book 33 SL 456 ...
# inserting Demo The Demo Book 33 SM 457 ...
# inserting Demo The Demo Book 33 SN 458 ...
# inserting Demo The Demo Book 33 SO 459 ...
# inserting Demo The Demo Book 33 SR 460 ...
# inserting Demo The Demo Book 33 SS 461 ...
# inserting Demo The Demo Book 33 ST 462 ...
# inserting Demo The Demo Book 33 SV 463 ...
# inserting Demo The Demo Book 33 SX 464 ...
# inserting Demo The Demo Book 33 SY 465 ...
# inserting Demo The Demo Book 33 SZ 466 ...
# inserting Demo The Demo Book 33 TC 467 ...
# inserting Demo The Demo Book 33 TD 468 ...
# inserting Demo The Demo Book 33 TF 469 ...
# inserting Demo The Demo Book 33 TG 470 ...
# inserting Demo The Demo Book 33 TH 471 ...
# inserting Demo The Demo Book 33 TJ 472 ...
# inserting Demo The Demo Book 33 TK 473 ...
# inserting Demo The Demo Book 33 TL 474 ...
# inserting Demo The Demo Book 33 TM 475 ...
# inserting Demo The Demo Book 33 TN 476 ...
# inserting Demo The Demo Book 33 TO 477 ...
# inserting Demo The Demo Book 33 TR 478 ...
# inserting Demo The Demo Book 33 TT 479 ...
# inserting Demo The Demo Book 33 TV 480 ...
# inserting Demo The Demo Book 33 TW 481 ...
# inserting Demo The Demo Book 33 TZ 482 ...
# inserting Demo The Demo Book 33 UA 483 ...
# inserting Demo The Demo Book 33 UG 484 ...
# inserting Demo The Demo Book 33 UM 485 ...
# inserting Demo The Demo Book 33 US 486 ...
# inserting Demo The Demo Book 33 UY 487 ...
# inserting Demo The Demo Book 33 UZ 488 ...
# inserting Demo The Demo Book 33 VA 489 ...
# inserting Demo The Demo Book 33 VC 490 ...
# inserting Demo The Demo Book 33 VE 491 ...
# inserting Demo The Demo Book 33 VG 492 ...
# inserting Demo The Demo Book 33 VI 493 ...
# inserting Demo The Demo Book 33 VN 494 ...
# inserting Demo The Demo Book 33 VU 495 ...
# inserting Demo The Demo Book 33 WF 496 ...
# inserting Demo The Demo Book 33 WS 497 ...
# inserting Demo The Demo Book 33 YE 498 ...
# inserting Demo The Demo Book 33 YT 499 ...
# inserting Demo The Demo Book 33 ZA 500 ...
# inserting Demo The Demo Book 33 ZM 501 ...
# inserting Demo The Demo Book 33 ZW 502 ...
# inserting Demo The Demo 2 Book 34 GB 330 ...
# inserting Demo The Demo 2 Book 34 IE 355 ...
# inserting Demo The Demo 2 Book 34 DE 310 ...
# inserting Demo The Demo 2 Book 34 FR 328 ...
# inserting Demo The Demo 2 Book 34 DK 312 ...
# inserting Demo The Demo 2 Book 34 US 486 ...
# inserting Demo The Demo 2 Book 34 CA 291 ...
# inserting Demo The Demo 3 Book 35 CH 296 ...
# inserting Demo The Demo 4 Book 36 AX 268 ...
# inserting Demo The Demo 4 Book 36 AL 259 ...
# inserting Demo The Demo 4 Book 36 DZ 315 ...
# inserting Demo The Demo 4 Book 36 AS 264 ...
# inserting Demo The Demo 4 Book 36 AD 254 ...
# inserting Demo The Demo 4 Book 36 AO 261 ...
# inserting Demo The Demo 4 Book 36 AI 258 ...
# inserting Demo The Demo 4 Book 36 AQ 262 ...
# inserting Demo The Demo 4 Book 36 AG 257 ...
# inserting Demo The Demo 4 Book 36 AR 263 ...
# inserting Demo The Demo 4 Book 36 AM 260 ...
# inserting Demo The Demo 4 Book 36 AW 267 ...
# inserting Demo The Demo 4 Book 36 AU 266 ...
# inserting Demo The Demo 4 Book 36 AT 265 ...
# inserting Demo The Demo 4 Book 36 AZ 269 ...
# inserting Demo The Demo 4 Book 36 BS 285 ...
# inserting Demo The Demo 4 Book 36 BH 276 ...
# inserting Demo The Demo 4 Book 36 BD 272 ...
# inserting Demo The Demo 4 Book 36 BB 271 ...
# inserting Demo The Demo 4 Book 36 BY 289 ...
# inserting Demo The Demo 4 Book 36 BE 273 ...
# inserting Demo The Demo 4 Book 36 BZ 290 ...
# inserting Demo The Demo 4 Book 36 BJ 278 ...
# inserting Demo The Demo 4 Book 36 BM 280 ...
# inserting Demo The Demo 4 Book 36 BT 286 ...
# inserting Demo The Demo 4 Book 36 BO 282 ...
# inserting Demo The Demo 4 Book 36 BA 270 ...
# inserting Demo The Demo 4 Book 36 BW 288 ...
# inserting Demo The Demo 4 Book 36 BV 287 ...
# inserting Demo The Demo 4 Book 36 BR 284 ...
# inserting Demo The Demo 4 Book 36 VG 492 ...
# inserting Demo The Demo 4 Book 36 IO 359 ...
# inserting Demo The Demo 4 Book 36 BN 281 ...
# inserting Demo The Demo 4 Book 36 BG 275 ...
# inserting Demo The Demo 4 Book 36 BF 274 ...
# inserting Demo The Demo 4 Book 36 BI 277 ...
# inserting Demo The Demo 4 Book 36 KH 370 ...
# inserting Demo The Demo 4 Book 36 CM 300 ...
# inserting Demo The Demo 4 Book 36 CA 291 ...
# inserting Demo The Demo 4 Book 36 CV 305 ...
# inserting Demo The Demo 4 Book 36 KY 377 ...
# inserting Demo The Demo 4 Book 36 CF 294 ...
# inserting Demo The Demo 4 Book 36 TD 468 ...
# inserting Demo The Demo 4 Book 36 CL 299 ...
# inserting Demo The Demo 4 Book 36 CN 301 ...
# inserting Demo The Demo 4 Book 36 HK 348 ...
# inserting Demo The Demo 4 Book 36 MO 401 ...
# inserting Demo The Demo 4 Book 36 CX 307 ...
# inserting Demo The Demo 4 Book 36 CC 292 ...
# inserting Demo The Demo 4 Book 36 CO 302 ...
# inserting Demo The Demo 4 Book 36 KM 372 ...
# inserting Demo The Demo 4 Book 36 CG 295 ...
# inserting Demo The Demo 4 Book 36 CD 293 ...
# inserting Demo The Demo 4 Book 36 CK 298 ...
# inserting Demo The Demo 4 Book 36 CR 303 ...
# inserting Demo The Demo 4 Book 36 CI 297 ...
# inserting Demo The Demo 4 Book 36 HR 351 ...
# inserting Demo The Demo 4 Book 36 CU 304 ...
# inserting Demo The Demo 4 Book 36 CY 308 ...
# inserting Demo The Demo 4 Book 36 CZ 309 ...
# inserting Demo The Demo 4 Book 36 DK 312 ...
# inserting Demo The Demo 4 Book 36 DJ 311 ...
# inserting Demo The Demo 4 Book 36 DM 313 ...
# inserting Demo The Demo 4 Book 36 DO 314 ...
# inserting Demo The Demo 4 Book 36 EC 316 ...
# inserting Demo The Demo 4 Book 36 EG 318 ...
# inserting Demo The Demo 4 Book 36 SV 463 ...
# inserting Demo The Demo 4 Book 36 GQ 341 ...
# inserting Demo The Demo 4 Book 36 ER 320 ...
# inserting Demo The Demo 4 Book 36 EE 317 ...
# inserting Demo The Demo 4 Book 36 ET 322 ...
# inserting Demo The Demo 4 Book 36 FK 325 ...
# inserting Demo The Demo 4 Book 36 FO 327 ...
# inserting Demo The Demo 4 Book 36 FJ 324 ...
# inserting Demo The Demo 4 Book 36 FI 323 ...
# inserting Demo The Demo 4 Book 36 FR 328 ...
# inserting Demo The Demo 4 Book 36 GF 333 ...
# inserting Demo The Demo 4 Book 36 PF 428 ...
# inserting Demo The Demo 4 Book 36 TF 469 ...
# inserting Demo The Demo 4 Book 36 GA 329 ...
# inserting Demo The Demo 4 Book 36 GM 338 ...
# inserting Demo The Demo 4 Book 36 GE 332 ...
# inserting Demo The Demo 4 Book 36 DE 310 ...
# inserting Demo The Demo 4 Book 36 GH 335 ...
# inserting Demo The Demo 4 Book 36 GI 336 ...
# inserting Demo The Demo 4 Book 36 GR 342 ...
# inserting Demo The Demo 4 Book 36 GL 337 ...
# inserting Demo The Demo 4 Book 36 GD 331 ...
# inserting Demo The Demo 4 Book 36 GP 340 ...
# inserting Demo The Demo 4 Book 36 GU 345 ...
# inserting Demo The Demo 4 Book 36 GT 344 ...
# inserting Demo The Demo 4 Book 36 GG 334 ...
# inserting Demo The Demo 4 Book 36 GN 339 ...
# inserting Demo The Demo 4 Book 36 GW 346 ...
# inserting Demo The Demo 4 Book 36 GY 347 ...
# inserting Demo The Demo 4 Book 36 HT 352 ...
# inserting Demo The Demo 4 Book 36 HM 349 ...
# inserting Demo The Demo 4 Book 36 VA 489 ...
# inserting Demo The Demo 4 Book 36 HN 350 ...
# inserting Demo The Demo 4 Book 36 HU 353 ...
# inserting Demo The Demo 4 Book 36 IS 362 ...
# inserting Demo The Demo 4 Book 36 IN 358 ...
# inserting Demo The Demo 4 Book 36 ID 354 ...
# inserting Demo The Demo 4 Book 36 IR 361 ...
# inserting Demo The Demo 4 Book 36 IQ 360 ...
# inserting Demo The Demo 4 Book 36 IE 355 ...
# inserting Demo The Demo 4 Book 36 IM 357 ...
# inserting Demo The Demo 4 Book 36 IL 356 ...
# inserting Demo The Demo 4 Book 36 IT 363 ...
# inserting Demo The Demo 4 Book 36 JM 365 ...
# inserting Demo The Demo 4 Book 36 JP 367 ...
# inserting Demo The Demo 4 Book 36 JE 364 ...
# inserting Demo The Demo 4 Book 36 JO 366 ...
# inserting Demo The Demo 4 Book 36 KZ 378 ...
# inserting Demo The Demo 4 Book 36 KE 368 ...
# inserting Demo The Demo 4 Book 36 KI 371 ...
# inserting Demo The Demo 4 Book 36 KP 374 ...
# inserting Demo The Demo 4 Book 36 KR 375 ...
# inserting Demo The Demo 4 Book 36 KW 376 ...
# inserting Demo The Demo 4 Book 36 KG 369 ...
# inserting Demo The Demo 4 Book 36 LA 379 ...
# inserting Demo The Demo 4 Book 36 LV 388 ...
# inserting Demo The Demo 4 Book 36 LB 380 ...
# inserting Demo The Demo 4 Book 36 LS 385 ...
# inserting Demo The Demo 4 Book 36 LR 384 ...
# inserting Demo The Demo 4 Book 36 LY 389 ...
# inserting Demo The Demo 4 Book 36 LI 382 ...
# inserting Demo The Demo 4 Book 36 LT 386 ...
# inserting Demo The Demo 4 Book 36 LU 387 ...
# inserting Demo The Demo 4 Book 36 MK 397 ...
# inserting Demo The Demo 4 Book 36 MG 395 ...
# inserting Demo The Demo 4 Book 36 MW 409 ...
# inserting Demo The Demo 4 Book 36 MY 411 ...
# inserting Demo The Demo 4 Book 36 MV 408 ...
# inserting Demo The Demo 4 Book 36 ML 398 ...
# inserting Demo The Demo 4 Book 36 MT 406 ...
# inserting Demo The Demo 4 Book 36 MH 396 ...
# inserting Demo The Demo 4 Book 36 MQ 403 ...
# inserting Demo The Demo 4 Book 36 MR 404 ...
# inserting Demo The Demo 4 Book 36 MU 407 ...
# inserting Demo The Demo 4 Book 36 YT 499 ...
# inserting Demo The Demo 4 Book 36 MX 410 ...
# inserting Demo The Demo 4 Book 36 FM 326 ...
# inserting Demo The Demo 4 Book 36 MD 392 ...
# inserting Demo The Demo 4 Book 36 MC 391 ...
# inserting Demo The Demo 4 Book 36 MN 400 ...
# inserting Demo The Demo 4 Book 36 ME 393 ...
# inserting Demo The Demo 4 Book 36 MS 405 ...
# inserting Demo The Demo 4 Book 36 MA 390 ...
# inserting Demo The Demo 4 Book 36 MZ 412 ...
# inserting Demo The Demo 4 Book 36 MM 399 ...
# inserting Demo The Demo 4 Book 36 NA 413 ...
# inserting Demo The Demo 4 Book 36 NR 422 ...
# inserting Demo The Demo 4 Book 36 NP 421 ...
# inserting Demo The Demo 4 Book 36 NL 419 ...
# skipping AN as ID is not found in permitted countries table
# inserting Demo The Demo 4 Book 36 NC 414 ...
# inserting Demo The Demo 4 Book 36 NZ 424 ...
# inserting Demo The Demo 4 Book 36 NI 418 ...
# inserting Demo The Demo 4 Book 36 NE 415 ...
# inserting Demo The Demo 4 Book 36 NG 417 ...
# inserting Demo The Demo 4 Book 36 NU 423 ...
# inserting Demo The Demo 4 Book 36 NF 416 ...
# inserting Demo The Demo 4 Book 36 MP 402 ...
# inserting Demo The Demo 4 Book 36 NO 420 ...
# inserting Demo The Demo 4 Book 36 OM 425 ...
# inserting Demo The Demo 4 Book 36 PK 431 ...
# inserting Demo The Demo 4 Book 36 PW 438 ...
# inserting Demo The Demo 4 Book 36 PS 436 ...
# inserting Demo The Demo 4 Book 36 PA 426 ...
# inserting Demo The Demo 4 Book 36 PG 429 ...
# inserting Demo The Demo 4 Book 36 PY 439 ...
# inserting Demo The Demo 4 Book 36 PE 427 ...
# inserting Demo The Demo 4 Book 36 PH 430 ...
# inserting Demo The Demo 4 Book 36 PN 434 ...
# inserting Demo The Demo 4 Book 36 PL 432 ...
# inserting Demo The Demo 4 Book 36 PT 437 ...
# inserting Demo The Demo 4 Book 36 PR 435 ...
# inserting Demo The Demo 4 Book 36 QA 440 ...
# inserting Demo The Demo 4 Book 36 RE 441 ...
# inserting Demo The Demo 4 Book 36 RO 442 ...
# inserting Demo The Demo 4 Book 36 RU 444 ...
# inserting Demo The Demo 4 Book 36 RW 445 ...
# inserting Demo The Demo 4 Book 36 BL 279 ...
# inserting Demo The Demo 4 Book 36 SH 452 ...
# inserting Demo The Demo 4 Book 36 KN 373 ...
# inserting Demo The Demo 4 Book 36 LC 381 ...
# inserting Demo The Demo 4 Book 36 MF 394 ...
# inserting Demo The Demo 4 Book 36 PM 433 ...
# inserting Demo The Demo 4 Book 36 VC 490 ...
# inserting Demo The Demo 4 Book 36 WS 497 ...
# inserting Demo The Demo 4 Book 36 SM 457 ...
# inserting Demo The Demo 4 Book 36 ST 462 ...
# inserting Demo The Demo 4 Book 36 SA 446 ...
# inserting Demo The Demo 4 Book 36 SN 458 ...
# inserting Demo The Demo 4 Book 36 RS 443 ...
# inserting Demo The Demo 4 Book 36 SC 448 ...
# inserting Demo The Demo 4 Book 36 SL 456 ...
# inserting Demo The Demo 4 Book 36 SG 451 ...
# inserting Demo The Demo 4 Book 36 SK 455 ...
# inserting Demo The Demo 4 Book 36 SI 453 ...
# inserting Demo The Demo 4 Book 36 SB 447 ...
# inserting Demo The Demo 4 Book 36 SO 459 ...
# inserting Demo The Demo 4 Book 36 ZA 500 ...
# inserting Demo The Demo 4 Book 36 GS 343 ...
# inserting Demo The Demo 4 Book 36 SS 461 ...
# inserting Demo The Demo 4 Book 36 ES 321 ...
# inserting Demo The Demo 4 Book 36 LK 383 ...
# inserting Demo The Demo 4 Book 36 SD 449 ...
# inserting Demo The Demo 4 Book 36 SR 460 ...
# inserting Demo The Demo 4 Book 36 SJ 454 ...
# inserting Demo The Demo 4 Book 36 SZ 466 ...
# inserting Demo The Demo 4 Book 36 SE 450 ...
# inserting Demo The Demo 4 Book 36 CH 296 ...
# inserting Demo The Demo 4 Book 36 SY 465 ...
# inserting Demo The Demo 4 Book 36 TW 481 ...
# inserting Demo The Demo 4 Book 36 TJ 472 ...
# inserting Demo The Demo 4 Book 36 TZ 482 ...
# inserting Demo The Demo 4 Book 36 TH 471 ...
# inserting Demo The Demo 4 Book 36 TL 474 ...
# inserting Demo The Demo 4 Book 36 TG 470 ...
# inserting Demo The Demo 4 Book 36 TK 473 ...
# inserting Demo The Demo 4 Book 36 TO 477 ...
# inserting Demo The Demo 4 Book 36 TT 479 ...
# inserting Demo The Demo 4 Book 36 TN 476 ...
# inserting Demo The Demo 4 Book 36 TR 478 ...
# inserting Demo The Demo 4 Book 36 TM 475 ...
# inserting Demo The Demo 4 Book 36 TC 467 ...
# inserting Demo The Demo 4 Book 36 TV 480 ...
# inserting Demo The Demo 4 Book 36 UG 484 ...
# inserting Demo The Demo 4 Book 36 UA 483 ...
# inserting Demo The Demo 4 Book 36 AE 255 ...
# inserting Demo The Demo 4 Book 36 GB 330 ...
# inserting Demo The Demo 4 Book 36 US 486 ...
# inserting Demo The Demo 4 Book 36 UM 485 ...
# inserting Demo The Demo 4 Book 36 UY 487 ...
# inserting Demo The Demo 4 Book 36 UZ 488 ...
# inserting Demo The Demo 4 Book 36 VU 495 ...
# inserting Demo The Demo 4 Book 36 VE 491 ...
# inserting Demo The Demo 4 Book 36 VN 494 ...
# inserting Demo The Demo 4 Book 36 VI 493 ...
# inserting Demo The Demo 4 Book 36 WF 496 ...
# inserting Demo The Demo 4 Book 36 EH 319 ...
# inserting Demo The Demo 4 Book 36 YE 498 ...
# inserting Demo The Demo 4 Book 36 ZM 501 ...
# inserting Demo The Demo 4 Book 36 ZW 502 ...
# skipping XX as ID is not found in permitted countries table
# finished, closing connection

# %%
#Now we've put the data in the database, we can query it! 
#Here's an example where we look at the countries an alphabetical order alongside the 
#books they have allocated to them.

conn = engine.connect()
bookResult = conn.execute(text("""
    SELECT * FROM Books B INNER JOIN BookRights BR ON BR.BookID = B.id INNER JOIN Countries C On BR.CountryID = C.id
    order by C.id;
    """))

items = bookResult.fetchall()
for item in items:
    print(item[1],",",item[5])
conn.close()
# Out:
# Demo The Demo Book , AD
# Demo The Demo 4 Book , AD
# Demo The Demo Book , AE
# Demo The Demo 4 Book , AE
# Demo The Demo Book , AF
# Demo The Demo Book , AG
# Demo The Demo 4 Book , AG
# Demo The Demo Book , AI
# Demo The Demo 4 Book , AI
# Demo The Demo Book , AL
# Demo The Demo 4 Book , AL
# Demo The Demo Book , AM
# Demo The Demo 4 Book , AM
# Demo The Demo Book , AO
# Demo The Demo 4 Book , AO
# Demo The Demo Book , AQ
# Demo The Demo 4 Book , AQ
# Demo The Demo Book , AR
# Demo The Demo 4 Book , AR
# Demo The Demo Book , AS
# Demo The Demo 4 Book , AS
# Demo The Demo Book , AT
# Demo The Demo 4 Book , AT
# Demo The Demo Book , AU
# Demo The Demo 4 Book , AU
# Demo The Demo Book , AW
# Demo The Demo 4 Book , AW
# Demo The Demo Book , AX
# Demo The Demo 4 Book , AX
# Demo The Demo Book , AZ
# Demo The Demo 4 Book , AZ
# Demo The Demo Book , BA
# Demo The Demo 4 Book , BA
# Demo The Demo Book , BB
# Demo The Demo 4 Book , BB
# Demo The Demo Book , BD
# Demo The Demo 4 Book , BD
# Demo The Demo Book , BE
# Demo The Demo 4 Book , BE
# Demo The Demo Book , BF
# Demo The Demo 4 Book , BF
# Demo The Demo Book , BG
# Demo The Demo 4 Book , BG
# Demo The Demo Book , BH
# Demo The Demo 4 Book , BH
# Demo The Demo Book , BI
# Demo The Demo 4 Book , BI
# Demo The Demo Book , BJ
# Demo The Demo 4 Book , BJ
# Demo The Demo Book , BL
# Demo The Demo 4 Book , BL
# Demo The Demo Book , BM
# Demo The Demo 4 Book , BM
# Demo The Demo Book , BN
# Demo The Demo 4 Book , BN
# Demo The Demo Book , BO
# Demo The Demo 4 Book , BO
# Demo The Demo Book , BQ
# Demo The Demo Book , BR
# Demo The Demo 4 Book , BR
# Demo The Demo Book , BS
# Demo The Demo 4 Book , BS
# Demo The Demo Book , BT
# Demo The Demo 4 Book , BT
# Demo The Demo Book , BV
# Demo The Demo 4 Book , BV
# Demo The Demo Book , BW
# Demo The Demo 4 Book , BW
# Demo The Demo Book , BY
# Demo The Demo 4 Book , BY
# Demo The Demo Book , BZ
# Demo The Demo 4 Book , BZ
# Demo The Demo Book , CA
# Demo The Demo 2 Book , CA
# Demo The Demo 4 Book , CA
# Demo The Demo Book , CC
# Demo The Demo 4 Book , CC
# Demo The Demo Book , CD
# Demo The Demo 4 Book , CD
# Demo The Demo Book , CF
# Demo The Demo 4 Book , CF
# Demo The Demo Book , CG
# Demo The Demo 4 Book , CG
# Demo The Demo Book , CH
# Demo The Demo 3 Book , CH
# Demo The Demo 4 Book , CH
# Demo The Demo Book , CI
# Demo The Demo 4 Book , CI
# Demo The Demo Book , CK
# Demo The Demo 4 Book , CK
# Demo The Demo Book , CL
# Demo The Demo 4 Book , CL
# Demo The Demo Book , CM
# Demo The Demo 4 Book , CM
# Demo The Demo Book , CN
# Demo The Demo 4 Book , CN
# Demo The Demo Book , CO
# Demo The Demo 4 Book , CO
# Demo The Demo Book , CR
# Demo The Demo 4 Book , CR
# Demo The Demo Book , CU
# Demo The Demo 4 Book , CU
# Demo The Demo Book , CV
# Demo The Demo 4 Book , CV
# Demo The Demo Book , CW
# Demo The Demo Book , CX
# Demo The Demo 4 Book , CX
# Demo The Demo Book , CY
# Demo The Demo 4 Book , CY
# Demo The Demo Book , CZ
# Demo The Demo 4 Book , CZ
# Demo The Demo Book , DE
# Demo The Demo 2 Book , DE
# Demo The Demo 4 Book , DE
# Demo The Demo Book , DJ
# Demo The Demo 4 Book , DJ
# Demo The Demo Book , DK
# Demo The Demo 2 Book , DK
# Demo The Demo 4 Book , DK
# Demo The Demo Book , DM
# Demo The Demo 4 Book , DM
# Demo The Demo Book , DO
# Demo The Demo 4 Book , DO
# Demo The Demo Book , DZ
# Demo The Demo 4 Book , DZ
# Demo The Demo Book , EC
# Demo The Demo 4 Book , EC
# Demo The Demo Book , EE
# Demo The Demo 4 Book , EE
# Demo The Demo Book , EG
# Demo The Demo 4 Book , EG
# Demo The Demo Book , EH
# Demo The Demo 4 Book , EH
# Demo The Demo Book , ER
# Demo The Demo 4 Book , ER
# Demo The Demo Book , ES
# Demo The Demo 4 Book , ES
# Demo The Demo Book , ET
# Demo The Demo 4 Book , ET
# Demo The Demo Book , FI
# Demo The Demo 4 Book , FI
# Demo The Demo Book , FJ
# Demo The Demo 4 Book , FJ
# Demo The Demo Book , FK
# Demo The Demo 4 Book , FK
# Demo The Demo Book , FM
# Demo The Demo 4 Book , FM
# Demo The Demo Book , FO
# Demo The Demo 4 Book , FO
# Demo The Demo Book , FR
# Demo The Demo 2 Book , FR
# Demo The Demo 4 Book , FR
# Demo The Demo Book , GA
# Demo The Demo 4 Book , GA
# Demo The Demo Book , GB
# Demo The Demo 2 Book , GB
# Demo The Demo 4 Book , GB
# Demo The Demo Book , GD
# Demo The Demo 4 Book , GD
# Demo The Demo Book , GE
# Demo The Demo 4 Book , GE
# Demo The Demo Book , GF
# Demo The Demo 4 Book , GF
# Demo The Demo Book , GG
# Demo The Demo 4 Book , GG
# Demo The Demo Book , GH
# Demo The Demo 4 Book , GH
# Demo The Demo Book , GI
# Demo The Demo 4 Book , GI
# Demo The Demo Book , GL
# Demo The Demo 4 Book , GL
# Demo The Demo Book , GM
# Demo The Demo 4 Book , GM
# Demo The Demo Book , GN
# Demo The Demo 4 Book , GN
# Demo The Demo Book , GP
# Demo The Demo 4 Book , GP
# Demo The Demo Book , GQ
# Demo The Demo 4 Book , GQ
# Demo The Demo Book , GR
# Demo The Demo 4 Book , GR
# Demo The Demo Book , GS
# Demo The Demo 4 Book , GS
# Demo The Demo Book , GT
# Demo The Demo 4 Book , GT
# Demo The Demo Book , GU
# Demo The Demo 4 Book , GU
# Demo The Demo Book , GW
# Demo The Demo 4 Book , GW
# Demo The Demo Book , GY
# Demo The Demo 4 Book , GY
# Demo The Demo Book , HK
# Demo The Demo 4 Book , HK
# Demo The Demo Book , HM
# Demo The Demo 4 Book , HM
# Demo The Demo Book , HN
# Demo The Demo 4 Book , HN
# Demo The Demo Book , HR
# Demo The Demo 4 Book , HR
# Demo The Demo Book , HT
# Demo The Demo 4 Book , HT
# Demo The Demo Book , HU
# Demo The Demo 4 Book , HU
# Demo The Demo Book , ID
# Demo The Demo 4 Book , ID
# Demo The Demo Book , IE
# Demo The Demo 2 Book , IE
# Demo The Demo 4 Book , IE
# Demo The Demo Book , IL
# Demo The Demo 4 Book , IL
# Demo The Demo Book , IM
# Demo The Demo 4 Book , IM
# Demo The Demo Book , IN
# Demo The Demo 4 Book , IN
# Demo The Demo Book , IO
# Demo The Demo 4 Book , IO
# Demo The Demo Book , IQ
# Demo The Demo 4 Book , IQ
# Demo The Demo Book , IR
# Demo The Demo 4 Book , IR
# Demo The Demo Book , IS
# Demo The Demo 4 Book , IS
# Demo The Demo Book , IT
# Demo The Demo 4 Book , IT
# Demo The Demo Book , JE
# Demo The Demo 4 Book , JE
# Demo The Demo Book , JM
# Demo The Demo 4 Book , JM
# Demo The Demo Book , JO
# Demo The Demo 4 Book , JO
# Demo The Demo Book , JP
# Demo The Demo 4 Book , JP
# Demo The Demo Book , KE
# Demo The Demo 4 Book , KE
# Demo The Demo Book , KG
# Demo The Demo 4 Book , KG
# Demo The Demo Book , KH
# Demo The Demo 4 Book , KH
# Demo The Demo Book , KI
# Demo The Demo 4 Book , KI
# Demo The Demo Book , KM
# Demo The Demo 4 Book , KM
# Demo The Demo Book , KN
# Demo The Demo 4 Book , KN
# Demo The Demo Book , KP
# Demo The Demo 4 Book , KP
# Demo The Demo Book , KR
# Demo The Demo 4 Book , KR
# Demo The Demo Book , KW
# Demo The Demo 4 Book , KW
# Demo The Demo Book , KY
# Demo The Demo 4 Book , KY
# Demo The Demo Book , KZ
# Demo The Demo 4 Book , KZ
# Demo The Demo Book , LA
# Demo The Demo 4 Book , LA
# Demo The Demo Book , LB
# Demo The Demo 4 Book , LB
# Demo The Demo Book , LC
# Demo The Demo 4 Book , LC
# Demo The Demo Book , LI
# Demo The Demo 4 Book , LI
# Demo The Demo Book , LK
# Demo The Demo 4 Book , LK
# Demo The Demo Book , LR
# Demo The Demo 4 Book , LR
# Demo The Demo Book , LS
# Demo The Demo 4 Book , LS
# Demo The Demo Book , LT
# Demo The Demo 4 Book , LT
# Demo The Demo Book , LU
# Demo The Demo 4 Book , LU
# Demo The Demo Book , LV
# Demo The Demo 4 Book , LV
# Demo The Demo Book , LY
# Demo The Demo 4 Book , LY
# Demo The Demo Book , MA
# Demo The Demo 4 Book , MA
# Demo The Demo Book , MC
# Demo The Demo 4 Book , MC
# Demo The Demo Book , MD
# Demo The Demo 4 Book , MD
# Demo The Demo Book , ME
# Demo The Demo 4 Book , ME
# Demo The Demo Book , MF
# Demo The Demo 4 Book , MF
# Demo The Demo Book , MG
# Demo The Demo 4 Book , MG
# Demo The Demo Book , MH
# Demo The Demo 4 Book , MH
# Demo The Demo Book , MK
# Demo The Demo 4 Book , MK
# Demo The Demo Book , ML
# Demo The Demo 4 Book , ML
# Demo The Demo Book , MM
# Demo The Demo 4 Book , MM
# Demo The Demo Book , MN
# Demo The Demo 4 Book , MN
# Demo The Demo Book , MO
# Demo The Demo 4 Book , MO
# Demo The Demo Book , MP
# Demo The Demo 4 Book , MP
# Demo The Demo Book , MQ
# Demo The Demo 4 Book , MQ
# Demo The Demo Book , MR
# Demo The Demo 4 Book , MR
# Demo The Demo Book , MS
# Demo The Demo 4 Book , MS
# Demo The Demo Book , MT
# Demo The Demo 4 Book , MT
# Demo The Demo Book , MU
# Demo The Demo 4 Book , MU
# Demo The Demo Book , MV
# Demo The Demo 4 Book , MV
# Demo The Demo Book , MW
# Demo The Demo 4 Book , MW
# Demo The Demo Book , MX
# Demo The Demo 4 Book , MX
# Demo The Demo Book , MY
# Demo The Demo 4 Book , MY
# Demo The Demo Book , MZ
# Demo The Demo 4 Book , MZ
# Demo The Demo Book , NA
# Demo The Demo 4 Book , NA
# Demo The Demo Book , NC
# Demo The Demo 4 Book , NC
# Demo The Demo Book , NE
# Demo The Demo 4 Book , NE
# Demo The Demo Book , NF
# Demo The Demo 4 Book , NF
# Demo The Demo Book , NG
# Demo The Demo 4 Book , NG
# Demo The Demo Book , NI
# Demo The Demo 4 Book , NI
# Demo The Demo Book , NL
# Demo The Demo 4 Book , NL
# Demo The Demo Book , NO
# Demo The Demo 4 Book , NO
# Demo The Demo Book , NP
# Demo The Demo 4 Book , NP
# Demo The Demo Book , NR
# Demo The Demo 4 Book , NR
# Demo The Demo Book , NU
# Demo The Demo 4 Book , NU
# Demo The Demo Book , NZ
# Demo The Demo 4 Book , NZ
# Demo The Demo Book , OM
# Demo The Demo 4 Book , OM
# Demo The Demo Book , PA
# Demo The Demo 4 Book , PA
# Demo The Demo Book , PE
# Demo The Demo 4 Book , PE
# Demo The Demo Book , PF
# Demo The Demo 4 Book , PF
# Demo The Demo Book , PG
# Demo The Demo 4 Book , PG
# Demo The Demo Book , PH
# Demo The Demo 4 Book , PH
# Demo The Demo Book , PK
# Demo The Demo 4 Book , PK
# Demo The Demo Book , PL
# Demo The Demo 4 Book , PL
# Demo The Demo Book , PM
# Demo The Demo 4 Book , PM
# Demo The Demo Book , PN
# Demo The Demo 4 Book , PN
# Demo The Demo Book , PR
# Demo The Demo 4 Book , PR
# Demo The Demo Book , PS
# Demo The Demo 4 Book , PS
# Demo The Demo Book , PT
# Demo The Demo 4 Book , PT
# Demo The Demo Book , PW
# Demo The Demo 4 Book , PW
# Demo The Demo Book , PY
# Demo The Demo 4 Book , PY
# Demo The Demo Book , QA
# Demo The Demo 4 Book , QA
# Demo The Demo Book , RE
# Demo The Demo 4 Book , RE
# Demo The Demo Book , RO
# Demo The Demo 4 Book , RO
# Demo The Demo Book , RS
# Demo The Demo 4 Book , RS
# Demo The Demo Book , RU
# Demo The Demo 4 Book , RU
# Demo The Demo Book , RW
# Demo The Demo 4 Book , RW
# Demo The Demo Book , SA
# Demo The Demo 4 Book , SA
# Demo The Demo Book , SB
# Demo The Demo 4 Book , SB
# Demo The Demo Book , SC
# Demo The Demo 4 Book , SC
# Demo The Demo Book , SD
# Demo The Demo 4 Book , SD
# Demo The Demo Book , SE
# Demo The Demo 4 Book , SE
# Demo The Demo Book , SG
# Demo The Demo 4 Book , SG
# Demo The Demo Book , SH
# Demo The Demo 4 Book , SH
# Demo The Demo Book , SI
# Demo The Demo 4 Book , SI
# Demo The Demo Book , SJ
# Demo The Demo 4 Book , SJ
# Demo The Demo Book , SK
# Demo The Demo 4 Book , SK
# Demo The Demo Book , SL
# Demo The Demo 4 Book , SL
# Demo The Demo Book , SM
# Demo The Demo 4 Book , SM
# Demo The Demo Book , SN
# Demo The Demo 4 Book , SN
# Demo The Demo Book , SO
# Demo The Demo 4 Book , SO
# Demo The Demo Book , SR
# Demo The Demo 4 Book , SR
# Demo The Demo Book , SS
# Demo The Demo 4 Book , SS
# Demo The Demo Book , ST
# Demo The Demo 4 Book , ST
# Demo The Demo Book , SV
# Demo The Demo 4 Book , SV
# Demo The Demo Book , SX
# Demo The Demo Book , SY
# Demo The Demo 4 Book , SY
# Demo The Demo Book , SZ
# Demo The Demo 4 Book , SZ
# Demo The Demo Book , TC
# Demo The Demo 4 Book , TC
# Demo The Demo Book , TD
# Demo The Demo 4 Book , TD
# Demo The Demo Book , TF
# Demo The Demo 4 Book , TF
# Demo The Demo Book , TG
# Demo The Demo 4 Book , TG
# Demo The Demo Book , TH
# Demo The Demo 4 Book , TH
# Demo The Demo Book , TJ
# Demo The Demo 4 Book , TJ
# Demo The Demo Book , TK
# Demo The Demo 4 Book , TK
# Demo The Demo Book , TL
# Demo The Demo 4 Book , TL
# Demo The Demo Book , TM
# Demo The Demo 4 Book , TM
# Demo The Demo Book , TN
# Demo The Demo 4 Book , TN
# Demo The Demo Book , TO
# Demo The Demo 4 Book , TO
# Demo The Demo Book , TR
# Demo The Demo 4 Book , TR
# Demo The Demo Book , TT
# Demo The Demo 4 Book , TT
# Demo The Demo Book , TV
# Demo The Demo 4 Book , TV
# Demo The Demo Book , TW
# Demo The Demo 4 Book , TW
# Demo The Demo Book , TZ
# Demo The Demo 4 Book , TZ
# Demo The Demo Book , UA
# Demo The Demo 4 Book , UA
# Demo The Demo Book , UG
# Demo The Demo 4 Book , UG
# Demo The Demo Book , UM
# Demo The Demo 4 Book , UM
# Demo The Demo Book , US
# Demo The Demo 2 Book , US
# Demo The Demo 4 Book , US
# Demo The Demo Book , UY
# Demo The Demo 4 Book , UY
# Demo The Demo Book , UZ
# Demo The Demo 4 Book , UZ
# Demo The Demo Book , VA
# Demo The Demo 4 Book , VA
# Demo The Demo Book , VC
# Demo The Demo 4 Book , VC
# Demo The Demo Book , VE
# Demo The Demo 4 Book , VE
# Demo The Demo Book , VG
# Demo The Demo 4 Book , VG
# Demo The Demo Book , VI
# Demo The Demo 4 Book , VI
# Demo The Demo Book , VN
# Demo The Demo 4 Book , VN
# Demo The Demo Book , VU
# Demo The Demo 4 Book , VU
# Demo The Demo Book , WF
# Demo The Demo 4 Book , WF
# Demo The Demo Book , WS
# Demo The Demo 4 Book , WS
# Demo The Demo Book , YE
# Demo The Demo 4 Book , YE
# Demo The Demo Book , YT
# Demo The Demo 4 Book , YT
# Demo The Demo Book , ZA
# Demo The Demo 4 Book , ZA
# Demo The Demo Book , ZM
# Demo The Demo 4 Book , ZM
# Demo The Demo Book , ZW
# Demo The Demo 4 Book , ZW

# %% [markdown]
# # tests thoughts
#
# ###### ONIX typically contains multiple products
#
# ##### is there a wrapping ONIXMessage declaration?
# ##### is there a header tag?
#
# ##### is there a product tag? case - no product tag - there can (and often is) multiple product tags
#
# ##### is there a territory tag? (should be within product tag) case- no territory tag
#
# ###### case- territory tag found outside product tag
#
# ##### what are the permitted country codes within the territory tag? (look to be typically 2 letters but can be 'WORLD')
#
# ##### case- unpermitted country code(s)
#
# ##### case- no country codes
#
# ##### multiple 'product', 'publishingdetail', 'salesrights', 'territory' tags
#
# ##### one or multiple tags missing in 'product', 'publishingdetail', 'salesrights', 'territory' chain
